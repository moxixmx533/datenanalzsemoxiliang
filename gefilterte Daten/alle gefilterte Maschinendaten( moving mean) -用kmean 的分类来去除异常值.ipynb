# %%
import pandas as pd
df1 = pd.read_excel("reine Daten mit Filter 14.10.19.xls")
df1.drop(['Unnamed: 0'], axis=1,inplace=True)
df2 = pd.read_excel("reine Daten mit Filter 16.10.19.xls")
df2.drop(['Unnamed: 0'], axis=1,inplace=True)
df3 = pd.read_excel("reine Daten mit Filter 21.10.19.xls")
df3.drop(['Unnamed: 0'], axis=1,inplace=True)
df4 = pd.read_excel("reine Daten mit Filter 23.10.19.xls")
df4.drop(['Unnamed: 0'], axis=1,inplace=True)
df5 = pd.read_excel("reine Daten mit Filter 25.10.19.xls")
df5.drop(['Unnamed: 0'], axis=1,inplace=True)
df6 = pd.read_excel("reine Daten mit Filter 28.10.19.xls")
df6.drop(['Unnamed: 0'], axis=1,inplace=True)
df7 = pd.read_excel("reine Daten mit Filter 30.10.19.xls")
df7.drop(['Unnamed: 0'], axis=1,inplace=True)
df8 = pd.read_excel("reine Daten mit Filter 06.11.19.xls")   
df8.drop(['Unnamed: 0'], axis=1,inplace=True)
df9 = pd.read_excel("reine Daten mit Filter 11.11.19.xls")  
df9.drop(['Unnamed: 0'], axis=1,inplace=True)
df9.drop([0],inplace=True)
df10 = pd.read_excel("reine Daten mit Filter 13.11.19.xls")
df10.drop(['Unnamed: 0'], axis=1,inplace=True)  
df11 = pd.read_excel("reine Daten mit Filter 18.11.19.xls")
df11.drop(['Unnamed: 0'], axis=1,inplace=True)  
df12 = pd.read_excel("reine Daten mit Filter 20.11.19.xls")
df12.drop(['Unnamed: 0'], axis=1,inplace=True)  
df13 = pd.read_excel("reine Daten mit Filter 25.11.19.xls")  
df13.drop([0],inplace=True)
df13.reset_index(drop=True, inplace=True)
df13.drop(['Unnamed: 0'], axis=1,inplace=True)  
df14 = pd.read_excel("reine Daten mit Filter 27.11.19.xls")
df14.drop(['Unnamed: 0'], axis=1,inplace=True)
df15 = pd.read_excel("reine Daten mit Filter 02.12.19.xls")
df15.drop(['Unnamed: 0.1'], axis=1,inplace=True)
df16 = pd.read_excel("reine Daten mit Filter 04.12.19.xls")
df16.drop(['Unnamed: 0'], axis=1,inplace=True)
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16],axis=0)
df.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\moxi\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df['activity from avtivitydaten'].unique()
# Out:
# array(['Hauptzeit - Verrohrung eindrehen', 'Hauptzeit - Ablassen',
#        'Hauptzeit - Ziehen', 'Nebenprozesszeit - Leeren',
#        'Hauptzeit - Bohren'], dtype=object)

# %%
df.drop(['Unnamed: 0'], axis=1,inplace=True)
df.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count              141928.0           141928.0    141928.000000
# mean                    0.0                0.0         0.002262
# std                     0.0                0.0         0.025207
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.710000
#
#        Crowd-Force [t]      Depth [m]  Gear Mode Main Winch []  \
# count    141928.000000  141928.000000            141928.000000
# mean         -0.780979      -9.791942                 1.341019
# std           8.440836      10.233691                 0.820573
# min         -40.320000     -42.509998                 0.000000
# 25%          -3.580000     -13.704000                 1.000000
# 50%           0.000000      -4.820000                 2.000000
# 75%           0.000000      -2.976000                 2.000000
# max          33.660000       0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count         141928.000000         141928.000000
# mean              -0.090739             -0.011240
# std                0.458383              0.642951
# min               -3.720000             -3.900000
# 25%               -0.060000             -0.080000
# 50%                0.000000              0.000000
# 75%                0.000000              0.000000
# max                2.740000              6.440000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  \
# count                   141928.000000          141928.000000
# mean                        10.912068              88.042069
# std                         14.943762             116.531848
# min                          0.000000               0.800000
# 25%                          0.004000               2.000000
# 50%                          3.472000              15.000000
# 75%                         14.946000             142.400000
# max                         62.321999             355.400000
#
#        Pressure Pump 2 [bar]  Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count          141928.000000          141928.000000          141928.000000
# mean              102.014303              65.198431              32.987832
# std               114.757873              64.888265              49.687942
# min                 0.400000               0.000000               0.200000
# 25%                 1.600000               0.000000               1.600000
# 50%                60.000000              55.200000              10.600000
# 75%               173.200000             115.600000              41.000000
# max               361.200000             343.600000             304.800000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count               141928.000000              141928.000000
# mean                     0.015678                  13.411589
# std                      0.359609                   4.221273
# min                      0.000000                   0.560000
# 25%                      0.000000                  11.980000
# 50%                      0.000000                  14.780000
# 75%                      0.000000                  16.600000
# max                     13.700000                  41.099999
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                  141928.000000        141928.0
# mean                        6.139934             0.0
# std                        10.094807             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.800000             0.0
# 75%                         9.600000             0.0
# max                        48.200000             0.0
#
#        Torque Steps [K=1;M=2;G=3]     Torque [%]   Torque [kNm]
# count               141928.000000  141928.000000  141928.000000
# mean                     2.806148      16.163083      64.012836
# std                      0.567528      28.897182     109.038200
# min                      1.000000       0.000000       0.000000
# 25%                      3.000000       0.000000       0.000000
# 50%                      3.000000       0.000000       4.800000
# 75%                      3.000000      19.000000      76.000000
# max                      3.000000     100.000000     390.000000

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df.hist(figsize=(20,15))

# %%
df_leeren = df.loc[df['activity from avtivitydaten']=='Nebenprozesszeit - Leeren']
df_leeren.reset_index(drop=True, inplace=True)

# %%
from sklearn.cluster import KMeans

# %%
data = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]
  
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(n_cluster, scores)
plt.xlabel('Cluster')
plt.ylabel('score')
plt.title('Elbow kurve')
plt.show()

# %%
X = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
X = X.reset_index(drop=True)
km = KMeans(n_clusters=10)
km.fit(X)
km.predict(X)
km
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = km.labels_
df1 = pd.DataFrame(data=labels,columns=['cluster'])
df1
# Out:
#        cluster
# 0            2
# 1            5
# 2            2
# 3            4
# 4            4
# ...        ...
# 27939        0
# 27940        0
# 27941        0
# 27942        0
# 27943        0
#
# [27944 rows x 1 columns]

# %%
df1['cluster'].unique()
# Out:
# array([2, 5, 4, 1, 8, 3, 6, 7, 0, 9], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
data11 = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
X = data11.values
  
#标准化处理,均值为0,标准差为1
X_std = StandardScaler().fit_transform(X)
data11 = pd.DataFrame(X_std)
  
  
kmeans = [KMeans(n_clusters=i).fit(data11) for i in n_cluster]
df_leeren['cluster'] = kmeans[9].predict(data11)
# Out:
# C:\Users\moxi\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_leeren['cluster'].unique()
# Out:
# array([1, 8, 9, 2, 3, 7, 5, 4, 0, 6], dtype=int64)

# %%
df_leeren.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count               27944.0            27944.0     27944.000000
# mean                    0.0                0.0         0.001062
# std                     0.0                0.0         0.022074
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.710000
#
#        Crowd-Force [t]     Depth [m]  Gear Mode Main Winch []  \
# count     27944.000000  27944.000000             27944.000000
# mean          3.491722     -2.447470                 1.461788
# std          13.249462      2.910600                 0.881487
# min         -37.200000    -37.853999                 0.000000
# 25%           0.000000     -3.632000                 0.000000
# 50%           0.000000     -1.804000                 2.000000
# 75%          12.700000     -0.570000                 2.000000
# max          31.400000      0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count          27944.000000          27944.000000
# mean              -0.239296             -0.286089
# std                0.686355              0.589579
# min               -3.580000             -3.900000
# 25%               -0.760000             -0.580000
# 50%               -0.120000             -0.100000
# 75%                0.180000              0.040000
# max                2.280000              3.900000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                    27944.000000           27944.000000  ...
# mean                        14.052940              21.060135  ...
# std                         11.994610              29.716705  ...
# min                          0.000000               1.000000  ...
# 25%                          4.622000               3.000000  ...
# 50%                         12.190000               7.600000  ...
# 75%                         21.114500              27.000000  ...
# max                         62.036001             267.600000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count           27944.000000           27944.000000
# mean              102.850551              85.809541
# std                55.876465              68.594187
# min                 0.000000               0.200000
# 25%                65.400000              17.600000
# 50%               102.200000              82.800000
# 75%               145.800000             135.400000
# max               343.200000             304.800000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                27944.000000               27944.000000
# mean                     0.001512                  15.110775
# std                      0.059598                   1.737889
# min                      0.000000                   1.180000
# 25%                      0.000000                  14.360000
# 50%                      0.000000                  15.040000
# 75%                      0.000000                  16.400000
# max                      4.220000                  25.720000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                   27944.000000         27944.0
# mean                        2.349284             0.0
# std                         3.964373             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         3.400000             0.0
# max                        35.800000             0.0
#
#        Torque Steps [K=1;M=2;G=3]    Torque [%]  Torque [kNm]       cluster
# count                27944.000000  27944.000000  27944.000000  27944.000000
# mean                     2.863541      1.393573      6.873819      4.047881
# std                      0.449777      3.804210     11.947336      2.633230
# min                      1.000000      0.000000      0.000000      0.000000
# 25%                      3.000000      0.000000      0.000000      2.000000
# 50%                      3.000000      0.000000      0.000000      3.000000
# 75%                      3.000000      0.000000      9.400000      7.000000
# max                      3.000000     48.000000     85.600000      9.000000
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster0 = df_leeren.loc[df_leeren['cluster']==0]
df_leeren_cluster0.reset_index(drop=True, inplace=True)
df_leeren_cluster0.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                 277.0              277.0            277.0
# mean                    0.0                0.0              0.0
# std                     0.0                0.0              0.0
# min                     0.0                0.0              0.0
# 25%                     0.0                0.0              0.0
# 50%                     0.0                0.0              0.0
# 75%                     0.0                0.0              0.0
# max                     0.0                0.0              0.0
#
#        Crowd-Force [t]   Depth [m]  Gear Mode Main Winch []  \
# count       277.000000  277.000000               277.000000
# mean          0.486931  -22.727004                 1.581227
# std           3.094341    6.806175                 0.482379
# min         -14.800000  -37.853999                 1.000000
# 25%           0.000000  -27.530000                 1.000000
# 50%           0.000000  -22.220000                 2.000000
# 75%           0.000000  -17.418000                 2.000000
# max          24.400000  -10.692000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count            277.000000            277.000000
# mean              -0.008087              0.031697
# std                0.024516              0.059846
# min               -0.100000             -0.120000
# 25%                0.000000              0.000000
# 50%                0.000000              0.000000
# 75%                0.000000              0.100000
# max                0.000000              0.100000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                      277.000000             277.000000  ...
# mean                        24.886874               3.825271  ...
# std                         13.005782              10.807570  ...
# min                          0.562000               1.600000  ...
# 25%                         14.888000               1.800000  ...
# 50%                         22.206000               2.000000  ...
# 75%                         29.716000               2.000000  ...
# max                         60.684000              78.000000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count             277.000000             277.000000
# mean              112.114801               5.759567
# std                44.051290              20.108858
# min                15.400000               1.000000
# 25%                88.800000               1.200000
# 50%               107.000000               1.200000
# 75%               159.200000               1.400000
# max               179.400000             157.200000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                       277.0                 277.000000
# mean                          0.0                  11.001083
# std                           0.0                   1.611309
# min                           0.0                   5.700000
# 25%                           0.0                  10.080000
# 50%                           0.0                  11.040000
# 75%                           0.0                  12.420000
# max                           0.0                  14.920000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                     277.000000           277.0
# mean                        0.270036             0.0
# std                         1.584391             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         0.000000             0.0
# max                        11.000000             0.0
#
#        Torque Steps [K=1;M=2;G=3]  Torque [%]  Torque [kNm]  cluster
# count                  277.000000  277.000000    277.000000    277.0
# mean                     2.992780    0.509025      2.063538      0.0
# std                      0.120168    3.169846     12.046204      0.0
# min                      1.000000    0.000000      0.000000      0.0
# 25%                      3.000000    0.000000      0.000000      0.0
# 50%                      3.000000    0.000000      0.000000      0.0
# 75%                      3.000000    0.000000      0.000000      0.0
# max                      3.000000   21.000000     84.800000      0.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster1 = df_leeren.loc[df_leeren['cluster']==1]
df_leeren_cluster1.reset_index(drop=True, inplace=True)
df_leeren_cluster1.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                5662.0             5662.0      5662.000000
# mean                    0.0                0.0         0.000335
# std                     0.0                0.0         0.003894
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.120000
#
#        Crowd-Force [t]    Depth [m]  Gear Mode Main Winch []  \
# count      5662.000000  5662.000000              5662.000000
# mean         21.151289    -2.264677                 1.494207
# std           5.632899     1.676977                 0.863578
# min          -2.360000    -9.490000                 0.000000
# 25%          16.280000    -3.479500                 1.000000
# 50%          22.140000    -2.098000                 2.000000
# 75%          26.180000    -0.848000                 2.000000
# max          31.400000     0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count           5662.000000           5662.000000
# mean              -0.275327             -0.400526
# std                0.615316              0.543924
# min               -2.240000             -2.820000
# 25%               -0.740000             -0.680000
# 50%               -0.200000             -0.270000
# 75%                0.120000             -0.020000
# max                1.760000              0.800000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                     5662.000000            5662.000000  ...
# mean                        19.682469              10.603850  ...
# std                          8.281022              12.273597  ...
# min                          0.000000               1.800000  ...
# 25%                         12.808500               3.400000  ...
# 50%                         20.704000               4.000000  ...
# 75%                         26.770500              14.200000  ...
# max                         49.078000              97.400000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count             5662.00000            5662.000000
# mean               163.48474             180.166973
# std                 31.22629              35.716322
# min                  0.00000              63.800000
# 25%                144.00000             155.600000
# 50%                169.40000             184.800000
# 75%                188.00000             208.000000
# max                266.20000             291.400000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                      5662.0                5662.000000
# mean                          0.0                  15.601353
# std                           0.0                   0.976977
# min                           0.0                  13.200000
# 25%                           0.0                  14.960000
# 50%                           0.0                  15.300000
# 75%                           0.0                  16.140000
# max                           0.0                  25.720000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                    5662.000000          5662.0
# mean                        1.068174             0.0
# std                         1.898953             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         1.600000             0.0
# max                        12.000000             0.0
#
#        Torque Steps [K=1;M=2;G=3]   Torque [%]  Torque [kNm]  cluster
# count                 5662.000000  5662.000000   5662.000000   5662.0
# mean                     2.966832     0.492935      3.431084      1.0
# std                      0.191633     2.082015      6.082706      0.0
# min                      1.000000     0.000000      0.000000      1.0
# 25%                      3.000000     0.000000      0.000000      1.0
# 50%                      3.000000     0.000000      0.000000      1.0
# 75%                      3.000000     0.000000      5.000000      1.0
# max                      3.000000    25.000000     46.200000      1.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster2 = df_leeren.loc[df_leeren['cluster']==2]
df_leeren_cluster2.reset_index(drop=True, inplace=True)
df_leeren_cluster2.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                4024.0             4024.0      4024.000000
# mean                    0.0                0.0         0.000222
# std                     0.0                0.0         0.006073
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.242000
#
#        Crowd-Force [t]    Depth [m]  Gear Mode Main Winch []  \
# count      4024.000000  4024.000000              4024.000000
# mean          3.856685    -3.252048                 1.530815
# std           7.060390     2.029639                 0.846654
# min         -24.260000    -7.476000                 0.000000
# 25%           0.000000    -4.894500                 2.000000
# 50%           0.000000    -3.211000                 2.000000
# 75%           5.360000    -1.565000                 2.000000
# max          27.660000     0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count           4024.000000           4024.000000
# mean              -0.413365             -0.490577
# std                0.758189              0.546223
# min               -2.040000             -2.120000
# 25%               -1.040000             -0.840000
# 50%               -0.480000             -0.440000
# 75%                0.200000              0.000000
# max                1.840000              1.080000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                     4024.000000            4024.000000  ...
# mean                        12.351625              36.136382  ...
# std                          7.613250              19.126875  ...
# min                          0.000000               1.200000  ...
# 25%                          6.745500              22.800000  ...
# 50%                         12.032000              33.800000  ...
# 75%                         17.245000              46.600000  ...
# max                         37.074000             130.800000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count            4024.000000            4024.000000
# mean               89.343887              56.727237
# std                39.636364              46.619777
# min                 0.000000               0.200000
# 25%                63.150000               9.950000
# 50%                88.200000              53.800000
# 75%               117.400000              85.600000
# max               195.400000             225.400000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                      4024.0                4024.000000
# mean                          0.0                  13.211963
# std                           0.0                   1.999544
# min                           0.0                   1.180000
# 25%                           0.0                  12.395000
# 50%                           0.0                  13.800000
# 75%                           0.0                  14.500000
# max                           0.0                  17.660000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                    4024.000000          4024.0
# mean                        7.707903             0.0
# std                         3.912780             0.0
# min                         0.000000             0.0
# 25%                         4.800000             0.0
# 50%                         7.600000             0.0
# 75%                        10.000000             0.0
# max                        22.200000             0.0
#
#        Torque Steps [K=1;M=2;G=3]   Torque [%]  Torque [kNm]  cluster
# count                 4024.000000  4024.000000   4024.000000   4024.0
# mean                     2.946223     3.533549     14.583300      2.0
# std                      0.197953     5.056417      8.467456      0.0
# min                      1.800000     0.000000      0.000000      2.0
# 25%                      3.000000     0.000000      8.800000      2.0
# 50%                      3.000000     0.000000     13.400000      2.0
# 75%                      3.000000     7.000000     19.800000      2.0
# max                      3.000000    23.000000     52.600000      2.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster3 = df_leeren.loc[df_leeren['cluster']==3]
df_leeren_cluster3.reset_index(drop=True, inplace=True)
df_leeren_cluster3.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                6184.0             6184.0      6184.000000
# mean                    0.0                0.0         0.000041
# std                     0.0                0.0         0.001326
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.080000
#
#        Crowd-Force [t]    Depth [m]  Gear Mode Main Winch []  \
# count      6184.000000  6184.000000              6184.000000
# mean         -0.622901    -0.901483                 1.108603
# std           5.114226     1.123103                 0.991853
# min         -30.560000    -9.540000                 0.000000
# 25%           0.000000    -1.208000                 0.000000
# 50%           0.000000    -0.510000                 2.000000
# 75%           0.000000    -0.056000                 2.000000
# max          23.720000     0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count           6184.000000           6184.000000
# mean              -0.021071              0.009874
# std                0.599716              0.482332
# min               -3.580000             -1.700000
# 25%               -0.300000             -0.080000
# 50%                0.000000              0.000000
# 75%                0.240000              0.100000
# max                2.140000              3.900000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                     6184.000000            6184.000000  ...
# mean                         7.393944              13.897930  ...
# std                          6.645333              20.923978  ...
# min                          0.000000               1.000000  ...
# 25%                          1.182000               2.000000  ...
# 50%                          6.528000               3.000000  ...
# 75%                         11.284500              18.400000  ...
# max                         41.120000             153.600000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count            6184.000000            6184.000000
# mean               76.886902              31.635996
# std                45.863969              37.568691
# min                 0.000000               0.400000
# 25%                47.550000               1.600000
# 50%                86.800000              15.000000
# 75%               106.000000              52.650000
# max               213.800000             220.600000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                 6184.000000                6184.000000
# mean                     0.000152                  15.053199
# std                      0.007269                   1.197657
# min                      0.000000                   7.460000
# 25%                      0.000000                  14.360000
# 50%                      0.000000                  14.760000
# 75%                      0.000000                  15.960000
# max                      0.460000                  19.500000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                    6184.000000          6184.0
# mean                        0.983215             0.0
# std                         1.659880             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         1.400000             0.0
# max                        10.800000             0.0
#
#        Torque Steps [K=1;M=2;G=3]   Torque [%]  Torque [kNm]  cluster
# count                 6184.000000  6184.000000   6184.000000   6184.0
# mean                     2.973706     0.642464      3.227102      3.0
# std                      0.144423     1.924605      5.740648      0.0
# min                      1.800000     0.000000      0.000000      3.0
# 25%                      3.000000     0.000000      0.000000      3.0
# 50%                      3.000000     0.000000      0.000000      3.0
# 75%                      3.000000     0.000000      5.200000      3.0
# max                      3.000000    19.000000     36.000000      3.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster4 = df_leeren.loc[df_leeren['cluster']==4]
df_leeren_cluster4.reset_index(drop=True, inplace=True)
df_leeren_cluster4.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                  33.0               33.0        33.000000
# mean                    0.0                0.0         0.599273
# std                     0.0                0.0         0.156107
# min                     0.0                0.0         0.290000
# 25%                     0.0                0.0         0.444000
# 50%                     0.0                0.0         0.710000
# 75%                     0.0                0.0         0.710000
# max                     0.0                0.0         0.710000
#
#        Crowd-Force [t]  Depth [m]  Gear Mode Main Winch []  \
# count        33.000000  33.000000                33.000000
# mean         -1.088485  -2.129152                 1.636364
# std           5.071247   1.366994                 0.783349
# min         -13.660000  -6.080000                 0.000000
# 25%           0.000000  -1.610000                 2.000000
# 50%           0.000000  -1.610000                 2.000000
# 75%           0.000000  -1.610000                 2.000000
# max           9.900000  -1.390000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count             33.000000             33.000000
# mean              -0.665455              0.003636
# std                0.279252              0.015374
# min               -0.800000              0.000000
# 25%               -0.800000              0.000000
# 50%               -0.800000              0.000000
# 75%               -0.800000              0.000000
# max                0.000000              0.080000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                       33.000000              33.000000  ...
# mean                         0.000848               5.551515  ...
# std                          0.003001              16.185953  ...
# min                          0.000000               1.200000  ...
# 25%                          0.000000               1.400000  ...
# 50%                          0.000000               1.600000  ...
# 75%                          0.000000               2.000000  ...
# max                          0.014000              83.600000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count              33.000000              33.000000
# mean                0.157576              13.193939
# std                 0.521435              17.449462
# min                 0.000000               1.000000
# 25%                 0.000000               1.000000
# 50%                 0.000000               1.000000
# 75%                 0.000000              29.200000
# max                 2.200000              58.800000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                        33.0                  33.000000
# mean                          0.0                   4.000606
# std                           0.0                   5.294057
# min                           0.0                   1.500000
# 25%                           0.0                   1.600000
# 50%                           0.0                   1.600000
# 75%                           0.0                   1.620000
# max                           0.0                  16.840001
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                      33.000000            33.0
# mean                        0.157576             0.0
# std                         0.697778             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         0.000000             0.0
# max                         3.800000             0.0
#
#        Torque Steps [K=1;M=2;G=3]  Torque [%]  Torque [kNm]  cluster
# count                        33.0        33.0     33.000000     33.0
# mean                          3.0         0.0      1.927273      4.0
# std                           0.0         0.0      7.948242      0.0
# min                           3.0         0.0      0.000000      4.0
# 25%                           3.0         0.0      0.000000      4.0
# 50%                           3.0         0.0      0.000000      4.0
# 75%                           3.0         0.0      0.000000      4.0
# max                           3.0         0.0     39.600000      4.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster5 = df_leeren.loc[df_leeren['cluster']==5]
df_leeren_cluster5.reset_index(drop=True, inplace=True)
df_leeren_cluster5.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                3104.0             3104.0      3104.000000
# mean                    0.0                0.0         0.002200
# std                     0.0                0.0         0.015593
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.302000
#
#        Crowd-Force [t]    Depth [m]  Gear Mode Main Winch []  \
# count      3104.000000  3104.000000              3104.000000
# mean         -7.431778    -3.407450                 1.591559
# std          12.468096     2.228417                 0.802795
# min         -29.500000   -12.880000                 0.000000
# 25%         -19.940000    -5.159500                 2.000000
# 50%          -7.840000    -3.556000                 2.000000
# 75%           0.025000    -1.639500                 2.000000
# max          25.840000     0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count           3104.000000           3104.000000
# mean              -0.448782             -0.672378
# std                0.744966              0.694352
# min               -2.540000             -3.900000
# 25%               -1.020000             -1.120000
# 50%               -0.680000             -0.600000
# 75%                0.160000             -0.040000
# max                1.600000              0.920000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                     3104.000000            3104.000000  ...
# mean                         4.482236               9.888660  ...
# std                          5.963766              17.624975  ...
# min                          0.000000               1.000000  ...
# 25%                          0.014000               3.000000  ...
# 50%                          1.866000               3.400000  ...
# 75%                          6.927500               9.600000  ...
# max                         32.930000             123.800000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count            3104.000000            3104.000000
# mean               54.730606              90.691430
# std                39.498629              34.138027
# min                 0.000000               0.800000
# 25%                22.150000              78.800000
# 50%                57.400000              96.600000
# 75%                84.650000             109.000000
# max               201.400000             245.400000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                      3104.0                3104.000000
# mean                          0.0                  16.619987
# std                           0.0                   1.109937
# min                           0.0                  13.140000
# 25%                           0.0                  16.180000
# 50%                           0.0                  16.700000
# 75%                           0.0                  17.140000
# max                           0.0                  23.380000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                    3104.000000          3104.0
# mean                        0.268750             0.0
# std                         0.698179             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         0.200000             0.0
# max                         7.800000             0.0
#
#        Torque Steps [K=1;M=2;G=3]   Torque [%]  Torque [kNm]  cluster
# count                 3104.000000  3104.000000   3104.000000   3104.0
# mean                     2.963144     0.326675      1.427964      5.0
# std                      0.182106     1.322449      3.178414      0.0
# min                      1.800000     0.000000      0.000000      5.0
# 25%                      3.000000     0.000000      0.000000      5.0
# 50%                      3.000000     0.000000      0.000000      5.0
# 75%                      3.000000     0.000000      1.000000      5.0
# max                      3.000000    18.000000     22.800000      5.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster6 = df_leeren.loc[df_leeren['cluster']==6]
df_leeren_cluster6.reset_index(drop=True, inplace=True)
df_leeren_cluster6.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                  20.0               20.0             20.0
# mean                    0.0                0.0              0.0
# std                     0.0                0.0              0.0
# min                     0.0                0.0              0.0
# 25%                     0.0                0.0              0.0
# 50%                     0.0                0.0              0.0
# 75%                     0.0                0.0              0.0
# max                     0.0                0.0              0.0
#
#        Crowd-Force [t]  Depth [m]  Gear Mode Main Winch []  \
# count         20.00000       20.0                     20.0
# mean          -3.11900        0.0                      0.0
# std            4.61969        0.0                      0.0
# min          -13.08000        0.0                      0.0
# 25%           -6.75500        0.0                      0.0
# 50%            0.00000        0.0                      0.0
# 75%            0.00000        0.0                      0.0
# max            0.00000        0.0                      0.0
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count             20.000000             20.000000
# mean              -0.869000              0.420000
# std                1.085182              1.419563
# min               -2.800000             -0.720000
# 25%               -1.435000             -0.395000
# 50%               -0.650000              0.040000
# 75%               -0.230000              0.290000
# max                0.580000              3.600000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                       20.000000               20.00000  ...
# mean                         0.208400               56.77000  ...
# std                          0.431335               28.90633  ...
# min                          0.000000               34.00000  ...
# 25%                          0.003000               35.00000  ...
# 50%                          0.010000               45.20000  ...
# 75%                          0.121500               60.30000  ...
# max                          1.412000              132.40000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count              20.000000              20.000000
# mean               22.650000              57.920000
# std                33.140332              41.190413
# min                 0.000000               1.200000
# 25%                 0.000000              20.350000
# 50%                 0.000000              59.200000
# 75%                45.700000             100.350000
# max                90.600000             115.400000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                   20.000000                  20.000000
# mean                     2.032000                  15.391000
# std                      0.916823                   0.704257
# min                      1.380000                  14.660000
# 25%                      1.380000                  14.875000
# 50%                      1.840000                  15.070000
# 75%                      2.145000                  16.205000
# max                      4.220000                  16.500000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                      20.000000            20.0
# mean                        0.300000             0.0
# std                         0.847287             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         0.000000             0.0
# max                         3.400000             0.0
#
#        Torque Steps [K=1;M=2;G=3]  Torque [%]  Torque [kNm]  cluster
# count                   20.000000    20.00000     20.000000     20.0
# mean                     2.300000     0.15000      1.020000      6.0
# std                      0.978721     0.67082      2.521403      0.0
# min                      1.000000     0.00000      0.000000      6.0
# 25%                      1.000000     0.00000      0.000000      6.0
# 50%                      3.000000     0.00000      0.000000      6.0
# 75%                      3.000000     0.00000      0.000000      6.0
# max                      3.000000     3.00000      8.000000      6.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster7 = df_leeren.loc[df_leeren['cluster']==7]
df_leeren_cluster7.reset_index(drop=True, inplace=True)
df_leeren_cluster7.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                5542.0             5542.0      5542.000000
# mean                    0.0                0.0         0.000004
# std                     0.0                0.0         0.000186
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.008000
#
#        Crowd-Force [t]    Depth [m]  Gear Mode Main Winch []  \
# count      5542.000000  5542.000000              5542.000000
# mean         -5.524110    -2.376435                 1.859293
# std          11.749694     2.000827                 0.504375
# min         -32.780000   -13.126000                 0.000000
# 25%         -18.260000    -3.370000                 2.000000
# 50%           0.000000    -1.816000                 2.000000
# 75%           1.655000    -0.856000                 2.000000
# max          22.020000     0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count           5542.000000           5542.000000
# mean              -0.126954             -0.022162
# std                0.603389              0.376522
# min               -1.580000             -1.660000
# 25%               -0.580000             -0.160000
# 50%               -0.060000              0.000000
# 75%                0.100000              0.180000
# max                2.200000              1.240000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                     5542.000000            5542.000000  ...
# mean                        25.813193               7.346012  ...
# std                         13.536478               8.019819  ...
# min                          1.398000               1.000000  ...
# 25%                         16.422500               2.400000  ...
# 50%                         22.052000               3.600000  ...
# 75%                         31.055000               9.800000  ...
# max                         62.036001              54.800000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count            5542.000000            5542.000000
# mean              126.549008              83.082606
# std                40.783555              52.850048
# min                31.200000               0.800000
# 25%                95.050000              50.200000
# 50%               123.600000              89.600000
# 75%               159.800000             108.400000
# max               260.600000             304.800000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                      5542.0                5542.000000
# mean                          0.0                  15.760956
# std                           0.0                   1.399226
# min                           0.0                  10.040000
# 25%                           0.0                  14.820000
# 50%                           0.0                  16.180000
# 75%                           0.0                  16.820000
# max                           0.0                  19.400000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                    5542.000000          5542.0
# mean                        0.721508             0.0
# std                         1.418610             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         0.800000             0.0
# max                         9.000000             0.0
#
#        Torque Steps [K=1;M=2;G=3]   Torque [%]  Torque [kNm]  cluster
# count                 5542.000000  5542.000000   5542.000000   5542.0
# mean                     2.957127     0.478888      2.035799      7.0
# std                      0.205173     1.613147      3.940454      0.0
# min                      1.000000     0.000000      0.000000      7.0
# 25%                      3.000000     0.000000      0.000000      7.0
# 50%                      3.000000     0.000000      0.000000      7.0
# 75%                      3.000000     0.000000      2.800000      7.0
# max                      3.000000    21.000000     36.000000      7.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster8 = df_leeren.loc[df_leeren['cluster']==8]
df_leeren_cluster8.reset_index(drop=True, inplace=True)
df_leeren_cluster8.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                1596.0             1596.0           1596.0
# mean                    0.0                0.0              0.0
# std                     0.0                0.0              0.0
# min                     0.0                0.0              0.0
# 25%                     0.0                0.0              0.0
# 50%                     0.0                0.0              0.0
# 75%                     0.0                0.0              0.0
# max                     0.0                0.0              0.0
#
#        Crowd-Force [t]    Depth [m]  Gear Mode Main Winch []  \
# count      1596.000000  1596.000000              1596.000000
# mean         -0.948647    -2.433677                 1.027569
# std           7.568185     1.997285                 0.998930
# min         -37.200000   -10.812000                 0.000000
# 25%           0.000000    -4.046500                 0.000000
# 50%           0.000000    -1.855000                 2.000000
# 75%           0.000000    -0.829500                 2.000000
# max          27.500000     0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count           1596.000000           1596.000000
# mean              -0.423596             -0.467306
# std                0.792565              0.668411
# min               -1.940000             -3.260000
# 25%               -1.020000             -0.740000
# 50%               -0.520000             -0.360000
# 75%                0.100000              0.000000
# max                1.880000              0.920000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                     1596.000000            1596.000000  ...
# mean                         8.266826              50.743734  ...
# std                         11.048022              41.984990  ...
# min                          0.000000               1.000000  ...
# 25%                          0.025500               9.950000  ...
# 50%                          4.339000              46.000000  ...
# 75%                         12.137000              80.200000  ...
# max                         61.450001             231.400000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count            1596.000000            1596.000000
# mean               67.559148              33.092356
# std                52.503853              45.265539
# min                 0.000000               0.600000
# 25%                24.750000               2.000000
# 50%                65.100000               3.800000
# 75%               103.000000              60.850000
# max               343.200000             210.800000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                 1596.000000                1596.000000
# mean                     0.000414                  14.682381
# std                      0.016521                   1.125168
# min                      0.000000                   8.340000
# 25%                      0.000000                  14.480000
# 50%                      0.000000                  14.820000
# 75%                      0.000000                  15.140000
# max                      0.660000                  18.520000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                    1596.000000          1596.0
# mean                        8.137469             0.0
# std                         7.553139             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         6.600000             0.0
# 75%                        13.400000             0.0
# max                        35.800000             0.0
#
#        Torque Steps [K=1;M=2;G=3]   Torque [%]  Torque [kNm]  cluster
# count                 1596.000000  1596.000000   1596.000000   1596.0
# mean                     1.221053     1.824561      8.550501      8.0
# std                      0.340028     3.738881      8.670335      0.0
# min                      1.000000     0.000000      0.000000      8.0
# 25%                      1.000000     0.000000      0.000000      8.0
# 50%                      1.000000     0.000000      6.700000      8.0
# 75%                      1.400000     1.000000     14.000000      8.0
# max                      2.200000    21.000000     50.800000      8.0
#
# [8 rows x 21 columns]

# %%
df_leeren_cluster9 = df_leeren.loc[df_leeren['cluster']==9]
df_leeren_cluster9.reset_index(drop=True, inplace=True)
df_leeren_cluster9.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count                1502.0             1502.0           1502.0
# mean                    0.0                0.0              0.0
# std                     0.0                0.0              0.0
# min                     0.0                0.0              0.0
# 25%                     0.0                0.0              0.0
# 50%                     0.0                0.0              0.0
# 75%                     0.0                0.0              0.0
# max                     0.0                0.0              0.0
#
#        Crowd-Force [t]    Depth [m]  Gear Mode Main Winch []  \
# count      1502.000000  1502.000000              1502.000000
# mean         14.185832    -1.938602                 1.328895
# std           9.005920     1.776440                 0.944681
# min          -9.040000    -6.142000                 0.000000
# 25%           6.935000    -3.281500                 0.000000
# 50%          17.170000    -1.480000                 2.000000
# 75%          22.380000    -0.150000                 2.000000
# max          27.720000     0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count           1502.000000           1502.000000
# mean              -0.346245             -0.582730
# std                0.811020              0.581435
# min               -2.100000             -1.940000
# 25%               -1.020000             -1.000000
# 50%               -0.400000             -0.480000
# 75%                0.240000             -0.120000
# max                2.280000              0.700000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                     1502.000000            1502.000000  ...
# mean                         5.835449              94.764714  ...
# std                          5.468358              40.762791  ...
# min                          0.000000               4.600000  ...
# 25%                          0.186500              66.800000  ...
# 50%                          5.162000              96.200000  ...
# 75%                         10.079500             120.100000  ...
# max                         27.562000             267.600000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count            1502.000000            1502.000000
# mean               68.482024             103.791212
# std                45.479541              59.457463
# min                 0.000000               1.000000
# 25%                31.200000              56.800000
# 50%                66.300000             116.400000
# 75%               106.350000             151.800000
# max               191.800000             226.000000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                      1502.0                1502.000000
# mean                          0.0                  14.521198
# std                           0.0                   0.753498
# min                           0.0                   5.440000
# 25%                           0.0                  14.180000
# 50%                           0.0                  14.540000
# 75%                           0.0                  14.900000
# max                           0.0                  17.560000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                    1502.000000          1502.0
# mean                        3.060852             0.0
# std                         3.220222             0.0
# min                         0.000000             0.0
# 25%                         0.400000             0.0
# 50%                         2.100000             0.0
# 75%                         4.600000             0.0
# max                        19.600000             0.0
#
#        Torque Steps [K=1;M=2;G=3]   Torque [%]  Torque [kNm]  cluster
# count                 1502.000000  1502.000000   1502.000000   1502.0
# mean                     2.973901     7.480027     42.608921      9.0
# std                      0.158644     8.875439     17.632814      0.0
# min                      1.000000     0.000000      0.000000      9.0
# 25%                      3.000000     0.000000     31.000000      9.0
# 50%                      3.000000     1.000000     43.000000      9.0
# 75%                      3.000000    17.000000     53.600000      9.0
# max                      3.000000    48.000000     85.600000      9.0
#
# [8 rows x 21 columns]

# %%
df_leeren1 = df_leeren[(df_leeren['cluster'] != 0)]
df_leeren1.describe()
# Out:
#        Boring threshold [m]  Casing Length [m]  Crowd Depth [m]  \
# count               27667.0            27667.0     27667.000000
# mean                    0.0                0.0         0.001073
# std                     0.0                0.0         0.022184
# min                     0.0                0.0         0.000000
# 25%                     0.0                0.0         0.000000
# 50%                     0.0                0.0         0.000000
# 75%                     0.0                0.0         0.000000
# max                     0.0                0.0         0.710000
#
#        Crowd-Force [t]     Depth [m]  Gear Mode Main Winch []  \
# count     27667.000000  27667.000000             27667.000000
# mean          3.521806     -2.244433                 1.460592
# std          13.308608      1.983785                 0.884496
# min         -37.200000    -13.126000                 0.000000
# 25%           0.000000     -3.573000                 0.000000
# 50%           0.000000     -1.768000                 2.000000
# 75%          12.940000     -0.564000                 2.000000
# max          31.400000      0.000000                 2.000000
#
#        Inclination X [Grad]  Inclination Y [Grad]  \
# count          27667.000000           27667.00000
# mean              -0.241611              -0.28927
# std                0.689386               0.59163
# min               -3.580000              -3.90000
# 25%               -0.760000              -0.60000
# 50%               -0.120000              -0.10000
# 75%                0.180000               0.04000
# max                2.280000               3.90000
#
#        Main Winch Rope Speed [cm/min]  Pressure Pump 1 [bar]  ...  \
# count                    27667.000000           27667.000000  ...
# mean                        13.944472              21.232689  ...
# std                         11.934686              29.795220  ...
# min                          0.000000               1.000000  ...
# 25%                          4.542000               3.000000  ...
# 50%                         12.078001               7.800000  ...
# 75%                         21.010000              27.200000  ...
# max                         62.036001             267.600000  ...
#
#        Pressure Pump 3 [bar]  Pressure Pump 4 [bar]  \
# count           27667.000000           27667.000000
# mean              102.757798              86.610995
# std                55.975108              68.435640
# min                 0.000000               0.200000
# 25%                65.400000              20.600000
# 50%               102.000000              83.600000
# 75%               145.600000             136.000000
# max               343.200000             304.800000
#
#        Rope Force Aux. Winch. [t]  Rope Force Main Winch [t]  \
# count                27667.000000               27667.000000
# mean                     0.001527                  15.151921
# std                      0.059895                   1.689320
# min                      0.000000                   1.180000
# 25%                      0.000000                  14.400000
# 50%                      0.000000                  15.060000
# 75%                      0.000000                  16.420000
# max                      4.220000                  25.720000
#
#        Speed of Rotary Drive [U/min]  Status Rig [ ]  \
# count                   27667.000000         27667.0
# mean                        2.370102             0.0
# std                         3.975531             0.0
# min                         0.000000             0.0
# 25%                         0.000000             0.0
# 50%                         0.000000             0.0
# 75%                         3.400000             0.0
# max                        35.800000             0.0
#
#        Torque Steps [K=1;M=2;G=3]    Torque [%]  Torque [kNm]       cluster
# count                27667.000000  27667.000000  27667.000000  27667.000000
# mean                     2.862247      1.402429      6.921979      4.088409
# std                      0.451677      3.809037     11.936764      2.614885
# min                      1.000000      0.000000      0.000000      1.000000
# 25%                      3.000000      0.000000      0.000000      2.000000
# 50%                      3.000000      0.000000      0.200000      3.000000
# 75%                      3.000000      0.000000      9.600000      7.000000
# max                      3.000000     48.000000     85.600000      9.000000
#
# [8 rows x 21 columns]

# %%
df_leeren1.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B802C688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B8076108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B80A2F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B80DF388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B810EF48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B8145CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B817DA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B81B47C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B81BA648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B81F25C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B8256088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B828E188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B82C6288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B83003C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B83384C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B8371608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3BCCFA748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3BCD33788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3BCD6B888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3BCDA29C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002D3BCDDCAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3BCE14BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3BCE4DDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B6351488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002D3B62DA4C8>]],
#       dtype=object)

# %% [markdown]
# ## Visualisierung der Eigenschaftsveränderung pro Prozess -->

# %% [markdown]
# ## Leeren

# %%
from matplotlib.dates import AutoDateLocator, DateFormatter
from pandas import DataFrame,Series

# %%
df_leeren = df.loc[df['activity from avtivitydaten']=='Nebenprozesszeit - Leeren']
df_leeren.reset_index(drop=True, inplace=True)

# %%
df_leeren.describe()

# %%
plt.figure(figsize=(30,25))  
df_leeren.boxplot(whis=3.0)
plt.xticks(rotation=45)

# %% [markdown]
# 下四分位数是Q1 0.25 上四分位数是Q3 0.75

# %%
x= df_leeren.time   #以时间作为坐标
y = df_leeren['Pressure Pump 1 [bar]']

ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M:%S'))  

plt.figure(figsize=(20,15))
plt.plot_date(x, y, fmt='b.')
plt.xticks(rotation=45)

# %%
x= df_leeren.time
y = df_leeren['Depth [m]']

ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M:%S'))  

plt.figure(figsize=(20,15))
plt.plot_date(x, y, fmt='b.')
plt.xticks(rotation=45)

# %% [markdown]
# # Anomale Daten zu finden am Beispiel Leeren. find outliers  用BOX来画图吧
#
#
# Box-Whisker-Plot  Kastengrafik Methode
# Box Verfahren kann die selbst definerten anomalen Daten finden und filtern, aber bei unserer Daten müssen wir zuerst überlegen, welche Eigenschaften wichtig für Zustand sind. Wenn die anomale Daten für alle Eigenschaften gefiltert wird, dann wird es viele Daten weggelassen, das ist nicht gewünscht. Z.b hier fast 10000 Daten für Leeren werden weggelassen.

# %% [markdown]
# ## Box Verfahren

# %%
df_leeren.describe()

# %% [markdown]
# ### Box Verfahren für Depth [m]

# %%
# Calculate first and third quartile
first_quartile = df_leeren['Depth [m]'].describe()['25%']
third_quartile = df_leeren['Depth [m]'].describe()['75%']

iqr = third_quartile - first_quartile
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_leeren_Depth_filter = df_leeren[(df_leeren['Depth [m]'] < (first_quartile - 3.0 * iqr))]
df_leeren_Depth_filter.describe() #这一段的数据怎么归类为其他的prozess，也有可能是Restprozess 所以这段数据不能用，unsicher zu festlegen

# %%
# Calculate first and third quartile
first_quartile = df_leeren['Depth [m]'].describe()['25%']
third_quartile = df_leeren['Depth [m]'].describe()['75%']

iqr = third_quartile - first_quartile
first_quartile - 1.5 * iqr

df_leeren_Depth_filter_middle_outlier = df_leeren[(df_leeren['Depth [m]'] < (first_quartile - 1.5 * iqr))]
df_leeren_Depth_filter_middle_outlier.describe()

# %% [markdown]
# ### Zusammenfassung: Es wird keine große Unterschiede(max_depth = -8.246m bei 1.5 und max_depth = -12.82m bei 3.0) zwischen 1.5 und 3.0.

# %%
# Remove outliers
df_leeren = df_leeren[(df_leeren['Depth [m]'] > (first_quartile - 3.0 * iqr)) &
            (df_leeren['Depth [m]'] < (third_quartile + 3.0 * iqr))]

# %%
df_leeren.describe()

# %% [markdown]
# ### Box Verfahren für Inclination Y

# %%
# Calculate first and third quartile
first_quartile = df_leeren['Inclination Y [Grad]'].describe()['25%']  
third_quartile = df_leeren['Inclination Y [Grad]'].describe()['75%']

iqr = third_quartile - first_quartile
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_leeren_Inclination_Y_filter = df_leeren[(df_leeren['Inclination Y [Grad]'] < (first_quartile - 3.0 * iqr))]
df_leeren_Inclination_Y_filter.describe()

# %%
df_leeren_Inclination_Y_filter = df_leeren[(df_leeren['Inclination Y [Grad]'] > (third_quartile + 3.0 * iqr))]
df_leeren_Inclination_Y_filter.describe()

# %%
# Remove outliers
df_leeren = df_leeren[(df_leeren['Inclination Y [Grad]'] > (first_quartile - 3.0 * iqr))&
            (df_leeren['Inclination Y [Grad]'] < (third_quartile + 3.0 * iqr))]

# %%
df_leeren.describe()

# %% [markdown]
# ### Box Verfahren für Pressure Pump 1 [bar]

# %%
# Calculate first and third quartile
first_quartile = df_leeren['Pressure Pump 1 [bar]'].describe()['25%']  
third_quartile = df_leeren['Pressure Pump 1 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_leeren_Pressure_Pump1 = df_leeren[(df_leeren['Pressure Pump 1 [bar]'] > (third_quartile + 3.0 * iqr))]
df_leeren_Pressure_Pump1.describe()

# %%
df_leeren_Pressure_Pump1 = df_leeren[(df_leeren['Pressure Pump 1 [bar]'] < (first_quartile - 3.0 * iqr))]
df_leeren_Pressure_Pump1.describe()

# %%
# Remove outliers
df_leeren = df_leeren[(df_leeren['Pressure Pump 1 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_leeren['Pressure Pump 1 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_leeren.describe()

# %% [markdown]
# ### Box Verfahren für Rope Force Main Winch [t]

# %%
first_quartile = df_leeren['Rope Force Main Winch [t]'].describe()['25%']
third_quartile = df_leeren['Rope Force Main Winch [t]'].describe()['75%']
iqr = third_quartile - first_quartile
iqr
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_leeren_Rope_Force_Main_Winch = df_leeren[(df_leeren['Rope Force Main Winch [t]'] < (first_quartile - 3.0 * iqr))]
df_leeren_Rope_Force_Main_Winch.describe()

# %%
df_leeren_Rope_Force_Main_Winch = df_leeren[(df_leeren['Rope Force Main Winch [t]'] > (third_quartile + 3.0 * iqr))]
df_leeren_Rope_Force_Main_Winch.describe()

# %%
# Remove outliers
df_leeren = df_leeren[(df_leeren['Rope Force Main Winch [t]'] > (first_quartile - 3.0 * iqr)) &
            (df_leeren['Rope Force Main Winch [t]'] < (third_quartile + 3.0 * iqr))]

# %%
df_leeren.describe()

# %% [markdown]
# ### Box Verfahren für Speed of Rotary Drive [U/min]

# %%
first_quartile = df_leeren['Speed of Rotary Drive [U/min]'].describe()['25%']
third_quartile = df_leeren['Speed of Rotary Drive [U/min]'].describe()['75%']
iqr = third_quartile - first_quartile
iqr
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_leeren_Speed_of_Rotary_Drive = df_leeren[(df_leeren['Speed of Rotary Drive [U/min]'] < (first_quartile - 3.0 * iqr))]
df_leeren_Speed_of_Rotary_Drive.describe()

# %%
df_leeren_Speed_of_Rotary_Drive = df_leeren[(df_leeren['Speed of Rotary Drive [U/min]'] > (third_quartile + 3.0 * iqr))]
df_leeren_Speed_of_Rotary_Drive.describe()

# %%
# Remove outliers
df_leeren = df_leeren[(df_leeren['Speed of Rotary Drive [U/min]'] > (first_quartile - 3.0 * iqr)) &
            (df_leeren['Speed of Rotary Drive [U/min]'] < (third_quartile + 3.0 * iqr))]

# %%
df_leeren.describe()

# %% [markdown]
# ### Box Verfahren für Drehmoment Torque [kNm]

# %%
first_quartile = df_leeren['Torque [kNm]'].describe()['25%']
third_quartile = df_leeren['Torque [kNm]'].describe()['75%']
iqr = third_quartile - first_quartile
iqr
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_leeren_Speed_of_Rotary_Drive = df_leeren[(df_leeren['Torque [kNm]'] < (first_quartile - 3.0 * iqr))]
df_leeren_Speed_of_Rotary_Drive.describe()

# %%
df_leeren_Speed_of_Rotary_Drive = df_leeren[(df_leeren['Torque [kNm]'] > (third_quartile + 3.0 * iqr))]
df_leeren_Speed_of_Rotary_Drive.describe()

# %%
# Remove outliers
df_leeren = df_leeren[(df_leeren['Torque [kNm]'] > (first_quartile - 3.0 * iqr)) &
            (df_leeren['Torque [kNm]'] < (third_quartile + 3.0 * iqr))]

# %%
# Calculate first and third quartile
first_quartile = df_leeren['Pressure Pump 1 [bar]'].describe()['25%']  
third_quartile = df_leeren['Pressure Pump 1 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_leeren_Pressure_Pump1 = df_leeren[(df_leeren['Pressure Pump 1 [bar]'] > (third_quartile + 3.0 * iqr))]
df_leeren_Pressure_Pump1.describe()

# %%
# Remove outliers
df_leeren = df_leeren[(df_leeren['Pressure Pump 1 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_leeren['Pressure Pump 1 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_leeren.describe()   #27944.0-24514.0 = 3430 points werden gefiltert.

# %%
plt.figure(figsize=(30,25))  
df_leeren.boxplot(whis=3.0)
plt.xticks(rotation=45)

# %% [markdown]
# Zusammenfassung: Ausreißer (für Drehmoment, Speed of Rotary Drive [U/min], Rope Force Main Winch [t], Pressure Pump 1 [bar], Inclination Y, Tiefe) werden gefiltert.

# %% [markdown]
# ## 因为数据是多维数据 打算用isolotion forest 方法来处理异常值

# %% [markdown]
# ## Ablassen

# %%
df_ablassen = df.loc[df['activity from avtivitydaten']=='Hauptzeit - Ablassen']
df_ablassen.reset_index(drop=True, inplace=True)
df_ablassen.describe()

# %%
plt.figure(figsize=(30,25))
df_ablassen.boxplot(whis=3.0)
plt.xticks(rotation=45)

# %%
x= df_ablassen.time
y = df_ablassen['Depth [m]']

ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M:%S'))  

plt.figure(figsize=(20,15))
plt.plot_date(x, y, fmt='b.')
plt.xticks(rotation=45)

# %%
# Calculate first and third quartile
first_quartile = df_ablassen['Pressure Pump 1 [bar]'].describe()['25%']
third_quartile = df_ablassen['Pressure Pump 1 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
first_quartile - 3.0 * iqr

# %%
third_quartile + 3.0 * iqr

# %%
df_ablassen_Pressure_Pump1 = df_ablassen[(df_ablassen['Pressure Pump 1 [bar]'] > (third_quartile + 3.0 * iqr))]
df_ablassen_Pressure_Pump1.describe()

# %%
# Remove outliers
df_ablassen = df_ablassen[(df_ablassen['Pressure Pump 1 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_ablassen['Pressure Pump 1 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_ablassen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_ablassen['Pressure Pump 2 [bar]'].describe()['25%']
third_quartile = df_ablassen['Pressure Pump 2 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_ablassen_Pressure_Pump2 = df_ablassen[(df_ablassen['Pressure Pump 2 [bar]'] > (third_quartile + 3.0 * iqr))]
df_ablassen_Pressure_Pump2.describe()

# %%
# Remove outliers
df_ablassen = df_ablassen[(df_ablassen['Pressure Pump 2 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_ablassen['Pressure Pump 2 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_ablassen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_ablassen['Pressure Pump 4 [bar]'].describe()['25%']
third_quartile = df_ablassen['Pressure Pump 4 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_ablassen_Pressure_Pump4 = df_ablassen[(df_ablassen['Pressure Pump 4 [bar]'] > (third_quartile + 3.0 * iqr))]
df_ablassen_Pressure_Pump4.describe()

# %%
# Remove outliers
df_ablassen = df_ablassen[(df_ablassen['Pressure Pump 4 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_ablassen['Pressure Pump 4 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_ablassen.describe()

# %%
plt.figure(figsize=(30,25))
df_ablassen.boxplot(whis=3.0)
plt.xticks(rotation=45)

# %% [markdown]
# Zusammenfassung:  Ausreißer (für Pressure Pump 1 [bar], Pressure Pump 2 [bar], Pressure Pump 4 [bar], Inclination X, Crowd Force) werden gefiltert. Die andere Ausreißer z.b für Drehmoment werden mit Box-Verfahren nicht behandelt, weil Werte 25% und 75% gleich null sind.

# %% [markdown]
# ## Bohren

# %%
df_Bohren = df.loc[df['activity from avtivitydaten']=='Hauptzeit - Bohren']
df_Bohren.reset_index(drop=True, inplace=True)
df_Bohren.describe()

# %%
plt.figure(figsize=(30,25))
df_Bohren.boxplot(whis=3)
plt.xticks(rotation=45)

# %%
x= df_Bohren.time
y = df_Bohren['Depth [m]']

ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M:%S'))  

plt.figure(figsize=(20,15))
plt.plot_date(x, y, fmt='b.')
plt.xticks(rotation=45)

# %%
# Calculate first and third quartile
first_quartile = df_Bohren['Pressure Pump 1 [bar]'].describe()['25%']
third_quartile = df_Bohren['Pressure Pump 1 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Bohren_Pressure_Pump1 = df_Bohren[(df_Bohren['Pressure Pump 1 [bar]'] > (third_quartile + 3.0 * iqr))]
df_Bohren_Pressure_Pump1.describe()

# %%
# Remove outliers
df_Bohren = df_Bohren[(df_Bohren['Pressure Pump 1 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_Bohren['Pressure Pump 1 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Bohren.describe()

# %%
# Calculate first and third quartile
first_quartile = df_Bohren['Pressure Pump 3 [bar]'].describe()['25%']
third_quartile = df_Bohren['Pressure Pump 3 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Bohren_Pressure_Pump3 = df_Bohren[(df_Bohren['Pressure Pump 3 [bar]'] > (third_quartile + 3.0 * iqr))]
df_Bohren_Pressure_Pump3.describe()

# %%
# Remove outliers
df_Bohren = df_Bohren[(df_Bohren['Pressure Pump 3 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_Bohren['Pressure Pump 3 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Bohren.describe()

# %%
# Calculate first and third quartile
first_quartile = df_Bohren['Pressure Pump 4 [bar]'].describe()['25%']
third_quartile = df_Bohren['Pressure Pump 4 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Bohren_Pressure_Pump4 = df_Bohren[(df_Bohren['Pressure Pump 4 [bar]'] > (third_quartile + 3.0 * iqr))]
df_Bohren_Pressure_Pump4.describe()

# %%
# Remove outliers
df_Bohren = df_Bohren[(df_Bohren['Pressure Pump 4 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_Bohren['Pressure Pump 4 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Bohren.describe()

# %%
# Calculate first and third quartile
first_quartile = df_Bohren['Torque [kNm]'].describe()['25%']
third_quartile = df_Bohren['Torque [kNm]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Bohren_Torque = df_Bohren[(df_Bohren['Torque [kNm]'] > (third_quartile + 3.0 * iqr))]
df_Bohren_Torque.describe()

# %%
# Remove outliers
df_Bohren = df_Bohren[(df_Bohren['Torque [kNm]'] > (first_quartile - 3.0 * iqr)) &
            (df_Bohren['Torque [kNm]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Bohren.describe()

# %% [markdown]
# Zusammenfassung: Ausreißer (für Pressure Pump 1 [bar], Pressure Pump 3 [bar], Pressure Pump 4 [bar], Torque [kNm]) werden gefiltert.

# %% [markdown]
# ## Ziehen

# %%
df_Ziehen = df.loc[df['activity from avtivitydaten']=='Hauptzeit - Ziehen']
df_Ziehen.reset_index(drop=True, inplace=True)
df_Ziehen.describe()

# %%
plt.figure(figsize=(30,25))
df_Ziehen.boxplot(whis=3)
plt.xticks(rotation=45)

# %%
x= df_Ziehen.time
y = df_Ziehen['Depth [m]']

ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M:%S'))  

plt.figure(figsize=(20,15))
plt.plot_date(x, y, fmt='b.')
plt.xticks(rotation=45)

# %%
# Calculate first and third quartile
first_quartile = df_Ziehen['Main Winch Rope Speed [cm/min]'].describe()['25%']
third_quartile = df_Ziehen['Main Winch Rope Speed [cm/min]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Ziehen_Main_Winch_Speed = df_Ziehen[(df_Ziehen['Main Winch Rope Speed [cm/min]'] > (third_quartile + 3.0 * iqr))]
df_Ziehen_Main_Winch_Speed.describe()

# %%
# Remove outliers
df_Ziehen = df_Ziehen[(df_Ziehen['Main Winch Rope Speed [cm/min]'] > (first_quartile - 3.0 * iqr)) &
            (df_Ziehen['Main Winch Rope Speed [cm/min]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Ziehen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_Ziehen['Pressure Pump 1 [bar]'].describe()['25%']
third_quartile = df_Ziehen['Pressure Pump 1 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Ziehen_Pressure_Pump1 = df_Ziehen[(df_Ziehen['Pressure Pump 1 [bar]'] > (third_quartile + 3.0 * iqr))]
df_Ziehen_Pressure_Pump1.describe()

# %%
# Remove outliers
df_Ziehen = df_Ziehen[(df_Ziehen['Pressure Pump 1 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_Ziehen['Pressure Pump 1 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Ziehen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_Ziehen['Pressure Pump 2 [bar]'].describe()['25%']
third_quartile = df_Ziehen['Pressure Pump 2 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Ziehen_Pressure_Pump2 = df_Ziehen[(df_Ziehen['Pressure Pump 2 [bar]'] > (third_quartile + 3.0 * iqr))]
df_Ziehen_Pressure_Pump2.describe()

# %%
# Remove outliers
df_Ziehen = df_Ziehen[(df_Ziehen['Pressure Pump 2 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_Ziehen['Pressure Pump 2 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Ziehen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_Ziehen['Pressure Pump 4 [bar]'].describe()['25%']
third_quartile = df_Ziehen['Pressure Pump 4 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
df_Ziehen_Pressure_Pump4 = df_Ziehen[(df_Ziehen['Pressure Pump 4 [bar]'] > (third_quartile + 3.0 * iqr))]
df_Ziehen_Pressure_Pump4.describe()

# %%
# Remove outliers
df_Ziehen = df_Ziehen[(df_Ziehen['Pressure Pump 4 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_Ziehen['Pressure Pump 4 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_Ziehen.describe()

# %% [markdown]
# Zusammenfassung: Ausreißer (für Pressure Pump 1 [bar], Pressure Pump 2 [bar], Pressure Pump 4 [bar], Main Winch Rope Speed [cm/min]) werden gefiltert.   33205.0-21886.0= 11319 Punkte werden gefiltert.

# %% [markdown]
# ## Verrohrung eindrehen

# %%
df_verrohrung_eindrehen = df.loc[df['activity from avtivitydaten']=='Hauptzeit - Verrohrung eindrehen']
df_verrohrung_eindrehen.reset_index(drop=True, inplace=True)
df_verrohrung_eindrehen.describe()

# %%
plt.figure(figsize=(30,25))
df_verrohrung_eindrehen.boxplot(whis=3)
plt.xticks(rotation=45)

# %%
x= df_verrohrung_eindrehen.time
y = df_verrohrung_eindrehen['Depth [m]']

ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M:%S'))  

plt.figure(figsize=(20,15))
plt.plot_date(x, y, fmt='b.')
plt.xticks(rotation=45)

# %%
# Calculate first and third quartile
first_quartile = df_verrohrung_eindrehen['Crowd-Force [t]'].describe()['25%']
third_quartile = df_verrohrung_eindrehen['Crowd-Force [t]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
first_quartile - 3.0 * iqr

# %%
df_verrohrung_eindrehen_crowd_force = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Crowd-Force [t]'] > (third_quartile + 3.0 * iqr))]
df_verrohrung_eindrehen_crowd_force.describe()

# %%
df_verrohrung_eindrehen_crowd_force = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Crowd-Force [t]'] < (first_quartile - 3.0 * iqr))]
df_verrohrung_eindrehen_crowd_force.describe()

# %%
# Remove outliers
df_verrohrung_eindrehen = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Crowd-Force [t]'] > (first_quartile - 3.0 * iqr)) &
            (df_verrohrung_eindrehen['Crowd-Force [t]'] < (third_quartile + 3.0 * iqr))]

# %%
df_verrohrung_eindrehen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_verrohrung_eindrehen['Depth [m]'].describe()['25%']
third_quartile = df_verrohrung_eindrehen['Depth [m]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
first_quartile - 3.0 * iqr

# %%
df_verrohrung_eindrehen_depth = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Depth [m]'] > (third_quartile + 3.0 * iqr))]
df_verrohrung_eindrehen_depth.describe()

# %%
df_verrohrung_eindrehen_depth = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Depth [m]'] < (first_quartile - 3.0 * iqr))]
df_verrohrung_eindrehen_depth.describe()

# %%
# Remove outliers
df_verrohrung_eindrehen = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Depth [m]'] > (first_quartile - 3.0 * iqr)) &
            (df_verrohrung_eindrehen['Depth [m]'] < (third_quartile + 3.0 * iqr))]

# %%
df_verrohrung_eindrehen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_verrohrung_eindrehen['Pressure Pump 4 [bar]'].describe()['25%']
third_quartile = df_verrohrung_eindrehen['Pressure Pump 4 [bar]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
first_quartile - 3.0 * iqr

# %%
df_verrohrung_eindrehen_depth = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Pressure Pump 4 [bar]'] > (third_quartile + 3.0 * iqr))]
df_verrohrung_eindrehen_depth.describe()

# %%
# Remove outliers
df_verrohrung_eindrehen = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Pressure Pump 4 [bar]'] > (first_quartile - 3.0 * iqr)) &
            (df_verrohrung_eindrehen['Pressure Pump 4 [bar]'] < (third_quartile + 3.0 * iqr))]

# %%
df_verrohrung_eindrehen.describe()

# %%
# Calculate first and third quartile
first_quartile = df_verrohrung_eindrehen['Rope Force Main Winch [t]'].describe()['25%']
third_quartile = df_verrohrung_eindrehen['Rope Force Main Winch [t]'].describe()['75%']

iqr = third_quartile - first_quartile
third_quartile + 3.0 * iqr

# %%
first_quartile - 3.0 * iqr

# %%
df_verrohrung_eindrehen_ropewinch = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Rope Force Main Winch [t]'] > (third_quartile + 3.0 * iqr))]
df_verrohrung_eindrehen_ropewinch.describe()

# %%
df_verrohrung_eindrehen_ropewinch = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Rope Force Main Winch [t]'] < (first_quartile - 3.0 * iqr))]
df_verrohrung_eindrehen_ropewinch.describe()

# %%
# Remove outliers
df_verrohrung_eindrehen = df_verrohrung_eindrehen[(df_verrohrung_eindrehen['Rope Force Main Winch [t]'] > (first_quartile - 3.0 * iqr)) &
            (df_verrohrung_eindrehen['Rope Force Main Winch [t]'] < (third_quartile + 3.0 * iqr))]

# %%
df_verrohrung_eindrehen.describe()

# %% [markdown]
# Zusammenfassung: Ausreißer (für 'Crowd-Force [t], Depth [m], Pressure Pump 4 [bar], Rope Force Main Winch [t] werden gefiltert.   42244-24464.0= 17780 Punkte werden gefiltert.

# %%
Es besteht keine Aussage über Zuordnung der gefilgterte Daten.

# %% [markdown]
# ## Local Outlier Factor

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor

# %%
def localoutlierfactor(data, predict, k):
    from sklearn.neighbors import LocalOutlierFactor
    clf = LocalOutlierFactor(n_neighbors=k + 1, algorithm='auto', contamination=0.1, n_jobs=-1)
    clf.fit(data)
    # 记录 k 邻域距离
    predict['k distances'] = clf.kneighbors(predict)[0].max(axis=1)
    # 记录 LOF 离群因子，做相反数处理
    predict['local outlier factor'] = -clf._decision_function(predict.iloc[:, :-1])
    return predict

def plot_lof(result, method):
    import matplotlib.pyplot as plt
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
    plt.figure(figsize=(8, 4)).add_subplot(111)
    plt.scatter(result[result['local outlier factor'] > method].index,
                result[result['local outlier factor'] > method]['local outlier factor'], c='red', s=50,
                marker='.', alpha=None,
                label='离群点')
    plt.scatter(result[result['local outlier factor'] <= method].index,
                result[result['local outlier factor'] <= method]['local outlier factor'], c='black', s=50,
                marker='.', alpha=None, label='正常点')
    plt.hlines(method, -2, 2 + max(result.index), linestyles='--')
    plt.xlim(-2, 2 + max(result.index))
    plt.title('LOF局部离群点检测', fontsize=13)
    plt.ylabel('局部离群因子', fontsize=15)
    plt.legend()
    plt.show()

def lof(data, predict=None, k=5, method=1, plot=False):
    import pandas as pd
    # 判断是否传入测试数据，若没有传入则测试数据赋值为训练数据
    try:
        if predict == None:
            predict = data.copy()
    except Exception:
        pass
    predict = pd.DataFrame(predict)
    # 计算 LOF 离群因子
    predict = localoutlierfactor(data, predict, k)
    if plot == True:
        plot_lof(predict, method)
    # 根据阈值划分离群点与正常点
    outliers = predict[predict['local outlier factor'] > method].sort_values(by='local outlier factor')
    inliers = predict[predict['local outlier factor'] <= method].sort_values(by='local outlier factor')
    return outliers, inliers

# %%
df_verrohrung_eindrehen = df.loc[df['activity from avtivitydaten']=='Hauptzeit - Verrohrung eindrehen']
df_verrohrung_eindrehen.reset_index(drop=True, inplace=True)
df_verrohrung_eindrehen.describe()

# %%
df_verrohrung_eindrehen.head()

# %%
df1 = df_verrohrung_eindrehen.drop(['activity from avtivitydaten','time'], axis=1)

# %%
outliers1, inliers2 = lof(df1, k=5, method = 1)  # method 指的是阈值， 通常是1. k指的是K距离邻域 #k 的值影响不大

# %%
outliers1

# %%
inliers2.describe()

# %%
df_leeren = df.loc[df['activity from avtivitydaten']=='Nebenprozesszeit - Leeren']
df_leeren.reset_index(drop=True, inplace=True)
df_leeren.describe()

# %%
df2 = df_leeren.drop(['activity from avtivitydaten','time'], axis=1)

# %%
outliers1, inliers1 = lof(df2, k=5, method = 1)

# %%
outliers1

# %%
inliers1.describe()

# %% [markdown]
# ## Isolotion Forest

# %%
df2 = df_leeren.drop(['activity from avtivitydaten','time'], axis=1)
df2.describe()

# %%
import pandas as pd                          
import numpy as np
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import MinMaxScaler

#read data
dataset = df2
#set variable
rs = np.random.RandomState(42);
outliers_fraction = 0.05;lendata = dataset.shape[0]
#label
anomaly = [];test_data = []
#sit normalize limited
nmlz_a = -1;nmlz_b = 1;

#some function is useful               ### 数值标准化
def normalize(dataset,a,b):
    scaler = MinMaxScaler(feature_range=(a, b))
    normalize_data = scaler.fit_transform(dataset)
    return normalize_data

#read dataset x,y
x = normalize(pd.DataFrame(dataset, columns=['Depth [m]']), nmlz_a, nmlz_b)
y1 = normalize(pd.DataFrame(dataset, columns=['Inclination X [Grad]']), nmlz_a, nmlz_b)
y2 = normalize(pd.DataFrame(dataset, columns=['Crowd Depth [m]']), nmlz_a, nmlz_b)
y3 = normalize(pd.DataFrame(dataset, columns=['Crowd-Force [t]']), nmlz_a, nmlz_b)
y4 = normalize(pd.DataFrame(dataset, columns=['Gear Mode Main Winch []']), nmlz_a, nmlz_b)
y5 = normalize(pd.DataFrame(dataset, columns=['Inclination Y [Grad]']), nmlz_a, nmlz_b)
y6 = normalize(pd.DataFrame(dataset, columns=['Main Winch Rope Speed [cm/min]']), nmlz_a, nmlz_b)
y7 = normalize(pd.DataFrame(dataset, columns=['Pressure Pump 1 [bar]']), nmlz_a, nmlz_b)
y8 = normalize(pd.DataFrame(dataset, columns=['Pressure Pump 2 [bar]']), nmlz_a, nmlz_b)
y9 = normalize(pd.DataFrame(dataset, columns=['Pressure Pump 3 [bar]']), nmlz_a, nmlz_b)
y10 = normalize(pd.DataFrame(dataset, columns=['Pressure Pump 4 [bar]']), nmlz_a, nmlz_b)
y11 = normalize(pd.DataFrame(dataset, columns=['Rope Force Aux. Winch. [t]']), nmlz_a, nmlz_b)
y12 = normalize(pd.DataFrame(dataset, columns=['Rope Force Main Winch [t]']), nmlz_a, nmlz_b)
y13 = normalize(pd.DataFrame(dataset, columns=['Speed of Rotary Drive [U/min]']), nmlz_a, nmlz_b)
y14 = normalize(pd.DataFrame(dataset, columns=['Status Rig [ ]']), nmlz_a, nmlz_b)
y15 = normalize(pd.DataFrame(dataset, columns=['Torque Steps [K=1;M=2;G=3]']), nmlz_a, nmlz_b)
y16 = normalize(pd.DataFrame(dataset, columns=['Torque [kNm]']), nmlz_a, nmlz_b)

#
ifm = IsolationForest(n_estimators=100, verbose=2, n_jobs=2,
                      max_samples=lendata, random_state=rs)

if __name__ == '__main__':
    Iso_train_dt = np.column_stack((x, y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16))
    ifm.fit(Iso_train_dt)
    scores_pred = ifm.decision_function(Iso_train_dt)

    threshold = stats.scoreatpercentile(scores_pred, 100 * outliers_fraction)
    # 使用预测值取5%分位数来定义阈值（基于小概率事件5%）
    # 根据训练样本中异常样本比例，得到阈值，用于绘图

    for i in scores_pred:
        if i <= threshold:
            #print(i)
            test_data.append(1)
            anomaly.append(i)
        else:
            test_data.append(0)

    print("孤立森林阈值  ：",threshold)
    print("全量数据样本数：",len(dataset),"个")
    print("检测异常样本数：",len(anomaly),"个")
    plt.show()

# %%
import pandas as pd                          
import numpy as np
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import MinMaxScaler

#read data
dataset = df2
#set variable
rs = np.random.RandomState(42);
outliers_fraction = 0.05;lendata = dataset.shape[0]
#label
anomaly = [];test_data = []

#
ifm = IsolationForest(n_estimators=100, verbose=2, n_jobs=2,
                      max_samples=lendata, random_state=rs)

if __name__ == '__main__':
    Iso_train_dt = df2
    ifm.fit(Iso_train_dt)
    scores_pred = ifm.decision_function(Iso_train_dt)

    threshold = stats.scoreatpercentile(scores_pred, 100 * outliers_fraction)
    # 使用预测值取5%分位数来定义阈值（基于小概率事件5%）
    # 根据训练样本中异常样本比例，得到阈值，用于绘图

    for i in scores_pred:
        if i <= threshold:
            #print(i)
            test_data.append(1)
            anomaly.append(i)
        else:
            test_data.append(0)

    print("孤立森林阈值  ：",threshold)
    print("全量数据样本数：",len(dataset),"个")
    print("检测异常样本数：",len(anomaly),"个")
    plt.show()

# %% [markdown]
# ### Anwendung verschiedener Methoden

# %%
pip install --upgrade pip

# %%
pip install pyod

# %%
df

# %%
df_leeren = df.loc[df['activity from avtivitydaten']=='Nebenprozesszeit - Leeren']
df_leeren.reset_index(drop=True, inplace=True)

# %%
df_leeren.describe()

# %%
from sklearn.cluster import KMeans

# %%
data = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]
  
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(n_cluster, scores)
plt.xlabel('Cluster')
plt.ylabel('score')
plt.title('Elbow kurve')
plt.show()

# %%
X = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
X = X.reset_index(drop=True)
km = KMeans(n_clusters=10)
km.fit(X)
km.predict(X)
km

# %%
labels = km.labels_
df1 = pd.DataFrame(data=labels,columns=['cluster'])
df1

# %%
data = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
X = data.values

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
#标准化处理,均值为0,标准差为1
X_std = StandardScaler().fit_transform(X)
mean_vec = np.mean(X_std, axis=0)
#计算协方差
cov_mat = np.cov(X_std.T)
  
#计算特征值和特征向量
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
  
#每个特征值对应一组特征向量
eig_pairs = [ (np.abs(eig_vals[i]),eig_vecs[:,i]) for i in range(len(eig_vals))]
eig_pairs.sort(key = lambda x: x[0], reverse= True)
  
#特征值求和
tot = sum(eig_vals)
  
#每个主要成分的解释方差
var_exp = [(i/tot)*100 for i in sorted(eig_vals, reverse=True)]
#累计的解释方差
cum_var_exp = np.cumsum(var_exp)
                
plt.figure(figsize=(10, 5))
plt.bar(range(len(var_exp)), var_exp, alpha=0.3, align='center', label='Independent variance', color = 'g')
plt.step(range(len(cum_var_exp)), cum_var_exp, where='mid',label='cumulative explained variance',)
plt.ylabel('the variance ratio')
plt.xlabel('principal component')
plt.legend(loc='best')
plt.show();

# %%
df2 = pd.DataFrame(data=cum_var_exp,columns=['cumulative explained variance'])
df2

# %%
from sklearn.decomposition import PCA

# %%
data = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
X = data.values
  
#标准化处理,均值为0,标准差为1
X_std = StandardScaler().fit_transform(X)
data = pd.DataFrame(X_std)
  
#将特征维度降到8
pca = PCA(n_components=8)
data = pca.fit_transform(data)
# 降维后将8个新特征进行标准化处理
scaler = StandardScaler()
np_scaled = scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)
  
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
data['cluster'] = kmeans[9].predict(data)

# %%
data.head()

# %%
data1=data.drop(['cluster'], axis=1)

# %%
df_leeren.index = data.index
df_leeren['principal_feature1'] = data[0]
df_leeren['principal_feature2'] = data[1]
df_leeren['principal_feature3'] = data[2]
df_leeren['principal_feature4'] = data[3]
df_leeren['principal_feature5'] = data[4]
df_leeren['principal_feature6'] = data[5]
df_leeren['principal_feature7'] = data[6]
df_leeren['principal_feature8'] = data[7]
df_leeren['cluster'] = data['cluster']
df_leeren.head()

# %%
def getDistanceByPoint(data, model):
    distance = pd.Series()
    for i in range(0,len(data)):
        Xa = np.array(data.loc[i])
        Xb = model.cluster_centers_[model.labels_[i]]
        distance.set_value(i, np.linalg.norm(Xa-Xb))
    return distance
  
#设置异常值比例
outliers_fraction = 0.2
  
# 得到每个点到取聚类中心的距离，我们设置了10个聚类中心，kmeans[9]表示有10个聚类中心的模型
distance = getDistanceByPoint(data1, kmeans[9])
  
#根据异常值比例outliers_fraction计算异常值的数量
number_of_outliers = int(outliers_fraction*len(distance))
  
#设定异常值的阈值
threshold = distance.nlargest(number_of_outliers).min()
  
#根据阈值来判断是否为异常值
data['anomaly1'] = (distance >= threshold).astype(int)

# %%
data['anomaly1'].unique()  #按照异常值的筛选不太符合想要的结果

# %%
data.head()

# %%
df_leeren['anomaly1'] = (distance >= threshold).astype(int)

# %%
df_leeren.head()

# %%
data_anomaly = df_leeren.loc[df_leeren['anomaly1']==1]
data_anomaly.reset_index(drop=True, inplace=True)
data_anomaly.describe()

# %%
data_nomaly = df_leeren.loc[df_leeren['anomaly1']==0]
data_nomaly.reset_index(drop=True, inplace=True)
data_nomaly.describe()

# %% [markdown]
# ### 不降维，直接用kmean之后的结果

# %%
data11 = df_leeren[['Crowd Depth [m]', 'Crowd-Force [t]', 'Depth [m]','Gear Mode Main Winch []','Inclination X [Grad]','Inclination Y [Grad]','Main Winch Rope Speed [cm/min]','Pressure Pump 1 [bar]','Pressure Pump 2 [bar]','Pressure Pump 3 [bar]','Pressure Pump 4 [bar]','Rope Force Aux. Winch. [t]','Rope Force Main Winch [t]','Speed of Rotary Drive [U/min]','Torque Steps [K=1;M=2;G=3]','Torque [kNm]']]
X = data11.values
  
#标准化处理,均值为0,标准差为1
X_std = StandardScaler().fit_transform(X)
data11 = pd.DataFrame(X_std)
  
  
kmeans = [KMeans(n_clusters=i).fit(data11) for i in n_cluster]
data11['cluster'] = kmeans[9].predict(data11)

# %%
data11

# %%
df_leeren.index = data.index
df_leeren['principal_feature1'] = data11[0]
df_leeren['principal_feature2'] = data11[1]
df_leeren['principal_feature3'] = data11[2]
df_leeren['principal_feature4'] = data11[3]
df_leeren['principal_feature5'] = data11[4]
df_leeren['principal_feature6'] = data11[5]
df_leeren['principal_feature7'] = data11[6]
df_leeren['principal_feature8'] = data11[7]
df_leeren['principal_feature9'] = data11[8]
df_leeren['principal_feature10'] = data11[9]
df_leeren['principal_feature11'] = data11[10]
df_leeren['principal_feature12'] = data11[11]
df_leeren['principal_feature13'] = data11[12]
df_leeren['principal_feature14'] = data11[13]
df_leeren['principal_feature15'] = data11[14]
df_leeren['principal_feature16'] = data11[15]
df_leeren['cluster'] = data11['cluster']
df_leeren.head()

# %% [markdown]
# ### 这里的聚类是PCA维度降到8之后，确定聚类的类型有10种，这里把其中感觉不合适的类型当成异常值去掉

# %%
df_leeren['cluster'].unique()

# %%
df_leeren_cluster1 = df_leeren.loc[df_leeren['cluster']==1]
df_leeren_cluster1.reset_index(drop=True, inplace=True)
df_leeren_cluster1.describe()

# %%
df_leeren_cluster2 = df_leeren.loc[df_leeren['cluster']==2]
df_leeren_cluster2.reset_index(drop=True, inplace=True)
df_leeren_cluster2.describe()

# %%
df_leeren_cluster3 = df_leeren.loc[df_leeren['cluster']==3]
df_leeren_cluster3.reset_index(drop=True, inplace=True)
df_leeren_cluster3.describe()

# %% [markdown]
# 画一个直方图，histogramm 关于depth 的， cluster 1-10的图

# %%
df_leeren_cluster4 = df_leeren.loc[df_leeren['cluster']==4]
df_leeren_cluster4.reset_index(drop=True, inplace=True)
df_leeren_cluster4.describe()

# %%
df_leeren_cluster5 = df_leeren.loc[df_leeren['cluster']==5]
df_leeren_cluster5.reset_index(drop=True, inplace=True)
df_leeren_cluster5.describe()

# %%
df_leeren_cluster6 = df_leeren.loc[df_leeren['cluster']==6]
df_leeren_cluster6.reset_index(drop=True, inplace=True)
df_leeren_cluster6.describe()

# %%
df_leeren_cluster7 = df_leeren.loc[df_leeren['cluster']==7]
df_leeren_cluster7.reset_index(drop=True, inplace=True)
df_leeren_cluster7.describe()

# %%
df_leeren_cluster8 = df_leeren.loc[df_leeren['cluster']==8]
df_leeren_cluster8.reset_index(drop=True, inplace=True)
df_leeren_cluster8.describe()

# %%
df_leeren_cluster9 = df_leeren.loc[df_leeren['cluster']==9]
df_leeren_cluster9.reset_index(drop=True, inplace=True)
df_leeren_cluster9.describe()

# %%
df_leeren1 = df_leeren[(df_leeren['cluster'] != 9)]
df_leeren1.describe()

# %%
df_leeren1['cluster'].unique()

# %%
df_leeren1.hist(figsize=(20,15))

# %% [markdown]
# ### Visualisierung Hist pro Eigenschaft pro Prozess, um wichtige Eigenschaften zu finden

# %%
df_verrohrung_eindrehen['Gear Mode Main Winch []'].hist(figsize=(30,25))
df_leeren['Gear Mode Main Winch []'].hist(figsize=(30,25))
df_ablassen['Gear Mode Main Winch []'].hist(figsize=(30,25))

# %%
首先要探讨一下一些过程状态下的常识，根据常识把一些异常值去掉。
在一个图里画5个过程的line 图， 用5种不同的颜色，x轴设为时间

# %%
df_leeren1 = df_leeren.describe()
df_ablassen1 = df_ablassen.describe()
df_Bohren1 = df_Bohren.describe()
df_Ziehen1 = df_Ziehen.describe()
df_verrohrung_eindrehen1 = df_verrohrung_eindrehen.describe()

# %%
df.head()

# %% [markdown]
# ### Eigenschaft: Tiefe(Depth)

# %%
data = {'Depth(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Depth(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Depth(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Depth(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Depth(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df2 = DataFrame(data)
   #df2['Depth(Leeren)'] = df_leeren1['Depth [m]'].values

# %%
df2['Depth(Leeren)'] = df_leeren1['Depth [m]'].values 
df2['Depth(Ablassen)'] = df_ablassen1['Depth [m]'].values
df2['Depth(Bohren)'] = df_Bohren1['Depth [m]'].values
df2['Depth(Ziehen)'] = df_Ziehen1['Depth [m]'].values
df2['Depth(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Depth [m]'].values

# %%
df2

# %% [markdown]
# ### Eigenschaft: Torque

# %%
data = {'Torque(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Torque(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Torque(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Torque(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Torque(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df3 = DataFrame(data)
  #df2['Depth(Leeren)'] = df_leeren1['Depth [m]'].values

# %%
df3['Torque(Leeren)'] = df_leeren1['Torque [kNm]'].values 
df3['Torque(Ablassen)'] = df_ablassen1['Torque [kNm]'].values
df3['Torque(Bohren)'] = df_Bohren1['Torque [kNm]'].values
df3['Torque(Ziehen)'] = df_Ziehen1['Torque [kNm]'].values
df3['Torque(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Torque [kNm]'].values 
df3

# %% [markdown]
# ### Eigenschaft: Rope Force Main Winch

# %%
data = {'Rope Force Main Winch(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Main Winch(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Main Winch(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Main Winch(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Main Winch(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df3 = DataFrame(data)

df3['Rope Force Main Winch(Leeren)'] = df_leeren1['Rope Force Main Winch [t]'].values 
df3['Rope Force Main Winch(Ablassen)'] = df_ablassen1['Rope Force Main Winch [t]'].values
df3['Rope Force Main Winch(Bohren)'] = df_Bohren1['Rope Force Main Winch [t]'].values
df3['Rope Force Main Winch(Ziehen)'] = df_Ziehen1['Rope Force Main Winch [t]'].values
df3['Rope Force Main Winch(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Rope Force Main Winch [t]'].values 
df3

# %% [markdown]
# ### Eigenschaft: Rope Force Aux. Winch. [t]

# %%
data = {'Rope Force Aux. Winch(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Aux. Winch(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Aux. Winch(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Aux. Winch(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Rope Force Aux. Winch(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df4 = DataFrame(data)

df4['Rope Force Aux. Winch(Leeren)'] = df_leeren1['Rope Force Aux. Winch. [t]'].values 
df4['Rope Force Aux. Winch(Ablassen)'] = df_ablassen1['Rope Force Aux. Winch. [t]'].values
df4['Rope Force Aux. Winch(Bohren)'] = df_Bohren1['Rope Force Aux. Winch. [t]'].values
df4['Rope Force Aux. Winch(Ziehen)'] = df_Ziehen1['Rope Force Aux. Winch. [t]'].values
df4['Rope Force Aux. Winch(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Rope Force Aux. Winch. [t]'].values 
df4

# %% [markdown]
# ### Eigenschaft: Speed of Rotary Drive [U/min]

# %%
data = {'Speed of Rotary Drive(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Speed of Rotary Drive(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Speed of Rotary Drive(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Speed of Rotary Drive(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Speed of Rotary Drive(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df5 = DataFrame(data)

df5['Speed of Rotary Drive(Leeren)'] = df_leeren1['Speed of Rotary Drive [U/min]'].values 
df5['Speed of Rotary Drive(Ablassen)'] = df_ablassen1['Speed of Rotary Drive [U/min]'].values
df5['Speed of Rotary Drive(Bohren)'] = df_Bohren1['Speed of Rotary Drive [U/min]'].values
df5['Speed of Rotary Drive(Ziehen)'] = df_Ziehen1['Speed of Rotary Drive [U/min]'].values
df5['Speed of Rotary Drive(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Speed of Rotary Drive [U/min]'].values 
df5

# %% [markdown]
# ### Eigenschaft: Pressure Pump 1 [bar]

# %%
data = {'Pressure Pump 1(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 1(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 1(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 1(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 1(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df6 = DataFrame(data)

df6['Pressure Pump 1(Leeren)'] = df_leeren1['Pressure Pump 1 [bar]'].values 
df6['Pressure Pump 1(Ablassen)'] = df_ablassen1['Pressure Pump 1 [bar]'].values
df6['Pressure Pump 1(Bohren)'] = df_Bohren1['Pressure Pump 1 [bar]'].values
df6['Pressure Pump 1(Ziehen)'] = df_Ziehen1['Pressure Pump 1 [bar]'].values
df6['Pressure Pump 1(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Pressure Pump 1 [bar]'].values 
df6

# %% [markdown]
# ### Eigenschaft: Pressure Pump 2 [bar]

# %%
data = {'Pressure Pump 2(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 2(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 2(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 2(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 2(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df7 = DataFrame(data)

df7['Pressure Pump 2(Leeren)'] = df_leeren1['Pressure Pump 2 [bar]'].values 
df7['Pressure Pump 2(Ablassen)'] = df_ablassen1['Pressure Pump 2 [bar]'].values
df7['Pressure Pump 2(Bohren)'] = df_Bohren1['Pressure Pump 2 [bar]'].values
df7['Pressure Pump 2(Ziehen)'] = df_Ziehen1['Pressure Pump 2 [bar]'].values
df7['Pressure Pump 2(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Pressure Pump 2 [bar]'].values 
df7

# %% [markdown]
# ### Eigenschaft: Pressure Pump 3 [bar]

# %%
data = {'Pressure Pump 3(Leeren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 3(Ablassen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 3(Bohren)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 3(Ziehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''},
       'Pressure Pump 3(Verrohrung eindrehen)':{'count':'','mean':'','std':'','min':'','25%':'','50%':'','75%':'','max':''}}
df8 = DataFrame(data)

df8['Pressure Pump 3(Leeren)'] = df_leeren1['Pressure Pump 3 [bar]'].values 
df8['Pressure Pump 3(Ablassen)'] = df_ablassen1['Pressure Pump 3 [bar]'].values
df8['Pressure Pump 3(Bohren)'] = df_Bohren1['Pressure Pump 3 [bar]'].values
df8['Pressure Pump 3(Ziehen)'] = df_Ziehen1['Pressure Pump 3 [bar]'].values
df8['Pressure Pump 3(Verrohrung eindrehen)'] = df_verrohrung_eindrehen1['Pressure Pump 3 [bar]'].values 
df8
